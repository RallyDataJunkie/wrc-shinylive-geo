# %% [markdown]
# # Scratchpad

# %%
from wrcapi_rallydj.data_api import WRCDataAPIClient
import pandas as pd

wrc = WRCDataAPIClient(usegeo=True)

# %%
#base=wrc.get_base_data()
#base

# %%
s = wrc.get_seasons()
s
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webappsdata.wrc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Event                                                          id  date-start  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5  84e-rallye-monte-carlo-2016  2016-01-22
# 25e409c3-4122-43b8-b145-3892a7994790                 rally-sweden  2016-02-12
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0      rally-guanajuato-mexico  2016-03-04
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc              rally-argentina  2016-04-21
# d5b87e31-fe70-436f-acfc-4b68962e23b4   vodafone-rally-de-portugal  2016-05-19
# ...                                                           ...         ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88                          NaN  2025-08-28
# 80566c83-ce79-41d8-90ba-c975f7f053e9                          NaN  2025-09-11
# be3f7d92-6751-4300-987c-3319925a91ee                          NaN  2025-10-16
# a7d33269-a190-43ff-8711-85d217035c1e                          NaN  2025-11-06
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5                          NaN  2025-11-27
#
# Event                                date-finish                         name  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5  2016-01-24  84e Rallye Monte-Carlo 2016
# 25e409c3-4122-43b8-b145-3892a7994790  2016-02-14                 Rally Sweden
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0  2016-03-06      Rally Guanajuato México
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc  2016-04-24              Rally Argentina
# d5b87e31-fe70-436f-acfc-4b68962e23b4  2016-05-22   Vodafone Rally de Portugal
# ...                                          ...                          ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88  2025-08-31           Rally del Paraguay
# 80566c83-ce79-41d8-90ba-c975f7f053e9  2025-09-14         Rally Chile Bio Bío
# be3f7d92-6751-4300-987c-3319925a91ee  2025-10-19       Central European Rally
# a7d33269-a190-43ff-8711-85d217035c1e  2025-11-09           FORUM8 Rally Japan
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5  2025-11-30           Rally Saudi Arabia
#
# Event                                    time-zone info-flag  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5         Paris       mon
# 25e409c3-4122-43b8-b145-3892a7994790     Stockholm       swe
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0   Mexico City       mex
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc  Buenos Aires       arg
# d5b87e31-fe70-436f-acfc-4b68962e23b4        Lisbon       por
# ...                                            ...       ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88           NaN       PRY
# 80566c83-ce79-41d8-90ba-c975f7f053e9           NaN       CHL
# be3f7d92-6751-4300-987c-3319925a91ee           NaN       EUR
# a7d33269-a190-43ff-8711-85d217035c1e           NaN       JPN
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5           NaN       SAU
#
# Event                                                         info-surface  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5  Asphalt, susceptible to ice and snow
# 25e409c3-4122-43b8-b145-3892a7994790           Ice and snow covered gravel
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0                                Gravel
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc                                Gravel
# d5b87e31-fe70-436f-acfc-4b68962e23b4                                Gravel
# ...                                                                    ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88                                Gravel
# 80566c83-ce79-41d8-90ba-c975f7f053e9                                Gravel
# be3f7d92-6751-4300-987c-3319925a91ee                                Tarmac
# a7d33269-a190-43ff-8711-85d217035c1e                                Tarmac
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5                                Gravel
#
# Event                                      info-date          info-categories  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5  22 - 24 Jan 16  WRC, WRC-2, WRC-3, JWRC
# 25e409c3-4122-43b8-b145-3892a7994790  12 - 14 Feb 16        WRC, WRC-2, WRC-3
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0    4 - 6 Mar 16        WRC, WRC-2, WRC-3
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc  21 - 24 Apr 16        WRC, WRC-2, WRC-3
# d5b87e31-fe70-436f-acfc-4b68962e23b4  19 - 22 May 16  WRC, WRC-2, WRC-3, JWRC
# ...                                              ...                      ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88  28 - 31 Aug 25                      NaN
# 80566c83-ce79-41d8-90ba-c975f7f053e9  11 - 14 Sep 25                      NaN
# be3f7d92-6751-4300-987c-3319925a91ee  16 - 19 Okt 25                      NaN
# a7d33269-a190-43ff-8711-85d217035c1e  06 - 09 Nov 25                      NaN
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5  27 - 30 Nov 25                      NaN
#
# Event                                               info-based  ...  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5            Gap and Monaco  ...
# 25e409c3-4122-43b8-b145-3892a7994790                  Karlstad  ...
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0                      Leon  ...
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc          Villa Carlos Paz  ...
# d5b87e31-fe70-436f-acfc-4b68962e23b4                Matosinhos  ...
# ...                                                        ...  ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88                    Itapúa  ...
# 80566c83-ce79-41d8-90ba-c975f7f053e9        Concepción, Biobío  ...
# be3f7d92-6751-4300-987c-3319925a91ee    Bad Griesbach, Germany  ...
# a7d33269-a190-43ff-8711-85d217035c1e  Toyota, Aichi Prefecture  ...
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5                     Bisha  ...
#
# Event                                sas-trackingid poilistid category  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5            NaN       NaN      NaN
# 25e409c3-4122-43b8-b145-3892a7994790            NaN       NaN      NaN
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0            NaN       NaN      NaN
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc            NaN       NaN      NaN
# d5b87e31-fe70-436f-acfc-4b68962e23b4            NaN       NaN      NaN
# ...                                             ...       ...      ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88           4217       NaN      WRC
# 80566c83-ce79-41d8-90ba-c975f7f053e9           4218       NaN      WRC
# be3f7d92-6751-4300-987c-3319925a91ee           4219       NaN      WRC
# a7d33269-a190-43ff-8711-85d217035c1e           4220       NaN      WRC
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5           4221       NaN      WRC
#
# Event                                availablility images hasdata  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5           NaN    NaN     NaN
# 25e409c3-4122-43b8-b145-3892a7994790           NaN    NaN     NaN
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0           NaN    NaN     NaN
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc           NaN    NaN     NaN
# d5b87e31-fe70-436f-acfc-4b68962e23b4           NaN    NaN     NaN
# ...                                            ...    ...     ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88           NaN    NaN     NaN
# 80566c83-ce79-41d8-90ba-c975f7f053e9           NaN    NaN     NaN
# be3f7d92-6751-4300-987c-3319925a91ee           NaN    NaN     NaN
# a7d33269-a190-43ff-8711-85d217035c1e           NaN    NaN     NaN
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5           NaN    NaN     NaN
#
# Event                                poi-Klo im Wald aws_folder avalability  \
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5             NaN        NaN         NaN
# 25e409c3-4122-43b8-b145-3892a7994790             NaN        NaN         NaN
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0             NaN        NaN         NaN
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc             NaN        NaN         NaN
# d5b87e31-fe70-436f-acfc-4b68962e23b4             NaN        NaN         NaN
# ...                                              ...        ...         ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88             NaN      pimuc         NaN
# 80566c83-ce79-41d8-90ba-c975f7f053e9             NaN      pimuc         NaN
# be3f7d92-6751-4300-987c-3319925a91ee             NaN      pimuc         NaN
# a7d33269-a190-43ff-8711-85d217035c1e             NaN      pimuc         NaN
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5             NaN      pimuc         NaN
#
# Event                                awsfolder
# 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5       NaN
# 25e409c3-4122-43b8-b145-3892a7994790       NaN
# 9ccc5470-5691-44c0-b8ed-d244d97a8ba0       NaN
# 2fbc34c2-77eb-49cc-851f-ea2be5220bcc       NaN
# d5b87e31-fe70-436f-acfc-4b68962e23b4       NaN
# ...                                        ...
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88       NaN
# 80566c83-ce79-41d8-90ba-c975f7f053e9       NaN
# be3f7d92-6751-4300-987c-3319925a91ee       NaN
# a7d33269-a190-43ff-8711-85d217035c1e       NaN
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5       NaN
#
# [161 rows x 38 columns]

# %%
s.iloc[0]
# Out:
# Event
# id                          84e-rallye-monte-carlo-2016
# date-start                                   2016-01-22
# date-finish                                  2016-01-24
# name                        84e Rallye Monte-Carlo 2016
# time-zone                                         Paris
# info-flag                                           mon
# info-surface       Asphalt, susceptible to ice and snow
# info-date                                22 - 24 Jan 16
# info-categories                 WRC, WRC-2, WRC-3, JWRC
# info-based                               Gap and Monaco
# info-website                                 www.acm.mc
# sitid                                               175
# logo                        images/monte_carlo_2016.png
# position                             7.421630,43.734607
# kmlfile                                 montecarlo_2016
# rosterid           7a0f4eb5-663d-42b5-93ab-8690a8aabbc2
# availability                                        now
# hasvideos                                          true
# _record_name                84e Rallye Monte-Carlo 2016
# year                                               2016
# tzoffset                                            NaN
# thumbnail                                           NaN
# gallery                                             NaN
# testid                                              NaN
# org-website                                         NaN
# sas-eventid                                         NaN
# sas-rallyid                                         NaN
# sas-itineraryid                                     NaN
# sas-trackingid                                      NaN
# poilistid                                           NaN
# category                                            NaN
# availablility                                       NaN
# images                                              NaN
# hasdata                                             NaN
# poi-Klo im Wald                                     NaN
# aws_folder                                          NaN
# avalability                                         NaN
# awsfolder                                           NaN
# Name: 6ad7a7fa-da2c-43bb-93c5-da788d0ab7a5, dtype: object

# %%
wrc.get_rallies_data(2025)
# Out:
# Event                                sas-eventid                        name  \
# 9d4dedf5-5ecb-44e2-92be-4fe799bf0b0e         534          Rallye Monte-Carlo
# 6964b894-571a-4825-8ed6-1a15be2f3fa5         535                Rally Sweden
# 35c61a2f-46b2-41b7-8af9-a19ceea5583d         536          Safari Rally Kenya
# e40db856-6faa-40a2-b0e9-41349d4454c3         538        Rally Islas Canarias
# 67930f8a-cf0b-4576-ae77-5ce1b5ec0cab         540  Vodafone Rally de Portugal
# 023eec1d-b076-490f-bed7-b3264643d90b         542       Rally Italia Sardegna
# 80930531-a7e9-4973-9ef2-6447a7289ed9         544  EKO Acropolis Rally Greece
# f986ea32-63ea-4b1e-860e-0d7656053288         546         Delfi Rally Estonia
# 0873c899-ce13-4e81-9c39-ac3f045986b1         547         Secto Rally Finland
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc88         549          Rally del Paraguay
# 80566c83-ce79-41d8-90ba-c975f7f053e9         551        Rally Chile Bio Bío
# be3f7d92-6751-4300-987c-3319925a91ee         553      Central European Rally
# a7d33269-a190-43ff-8711-85d217035c1e         554          FORUM8 Rally Japan
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5         555          Rally Saudi Arabia
#
# Event                                sitid sas-rallyid sas-itineraryid  \
# 9d4dedf5-5ecb-44e2-92be-4fe799bf0b0e   534         582            1119
# 6964b894-571a-4825-8ed6-1a15be2f3fa5   535         583            1137
# 35c61a2f-46b2-41b7-8af9-a19ceea5583d   536         584            1155
# e40db856-6faa-40a2-b0e9-41349d4454c3   538         586            1072
# 67930f8a-cf0b-4576-ae77-5ce1b5ec0cab   540         588            1074
# 023eec1d-b076-490f-bed7-b3264643d90b   542         590            1076
# 80930531-a7e9-4973-9ef2-6447a7289ed9   544         592            1078
# f986ea32-63ea-4b1e-860e-0d7656053288   546         594            1080
# 0873c899-ce13-4e81-9c39-ac3f045986b1   547         595            1081
# c19fefaf-6431-4c00-a1f4-fd5e1ce2cc
# 80566c83-ce79-41d8-90ba-c975f7f053e9       NaN
# be3f7d92-6751-4300-987c-3319925a91ee       NaN
# a7d33269-a190-43ff-8711-85d217035c1e       NaN
# 262dfb70-f69d-4999-b3ea-5fe7189c59b5       NaN
#
# [14 rows x 26 columns]

# %%
wrc.get_rallies_data(2025).iloc[2]
# Out:
# Event
# sas-eventid                                         536
# name                                 Safari Rally Kenya
# sitid                                               536
# sas-rallyid                                         584
# sas-itineraryid                                    1155
# sas-trackingid                                     4210
# date-start                                   2025-03-20
# date-finish                                  2025-03-23
# info-date                                20 - 23 Mrz 25
# info-based                                      Nairobi
# info-surface                                     Gravel
# info-flag                                           KEN
# info-website                         www.safarirally.ke
# tzoffset                                       36000000
# category                                            WRC
# position           36.4505913051399, -0.744037435960323
# poilistid          0be36f8b-785b-442b-aff5-4c713b177cf5
# logo                              images/kenya_2025.png
# kmlfile                                      kenya_2025
# rosterid           5f54d547-188f-4870-a85e-5e3d866a0821
# aws_folder                                        pimuc
# availability                                        now
# hasvideos                                          true
# _record_name                         Safari Rally Kenya
# year                                               2025
# awsfolder                                           NaN
# Name: 35c61a2f-46b2-41b7-8af9-a19ceea5583d, dtype: object

# %%
# df_rosterEntry, df_car, df_biog, df_team = wrc.process_roster_data(
#    wrc.get_rallies_data(2025), rally="Rallye Monte-Carlo"
# )
df_rosterEntry, df_car, df_biog, df_team = wrc.process_roster_data(
    wrc.get_rallies_data(2025), rallyname="Safari Rally Kenya", category="all"
)

df_rosterEntry.reset_index()#.head(3)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webappsdata.wrc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#     index                        _rosterentryID driverCode sas-entryid fiasn  \
# 0       0  f6cd659d-3e2f-43e0-b6dc-58ad2873ffec        EVA       54972    97
# 1       1  af059b41-d4b2-4484-8844-3991a0f3c846        ROV       54973    95
# 2       2  55d6262a-a0a3-4c79-be48-e1574336bae3        NEU       54974   100
# 3       3  a3beeba9-2691-42f9-ac06-0023aa5966d8        TAN       54975    73
# 4       4  b0c35896-b838-4fdb-b011-a0f71cdab1c0        KAT       54976    96
# 5       5  99bf7165-6a90-4597-a6f0-0496fdb87e56        FOU       54977    99
# 6       6  09cda572-106f-49c4-aeeb-ca4337b6ed56        MCE       54978    57
# 7       7  d95123dc-7aa1-4166-a005-db068f24b023        PAJ       54979   105
# 8       8  902f4104-0b71-4f75-a4b8-dd62ece91809        MUN       54980    83
# 9       9  4a531090-de06-4b71-9b32-7c70f1818cdf        SER       54981   110
# 10     10  56b87915-60a6-44e2-b5ec-77adf0037278        SOL       54982   NaN
# 11     11  088b426f-7508-4ef3-b9b5-eeb56a6ebc7e        ZAL       54983   NaN
# 12     12  079fae64-b2ed-4556-9690-b9ac6e7cd454        GRE       54984   NaN
# 13     13  df4e452d-8d92-4bcd-a970-d5321c17d528        JSO       54985   NaN
# 14     14  2dead723-0a54-4d9e-9960-f1bb452e43db        KAJ       54986   NaN
# 15     15  33bcb4c4-630f-41eb-b7d7-bde4d14ceb5d        DOM       54987   NaN
# 16     16  6673281a-5466-4769-b1e8-4c29a9e4a4d6        PAT       54988   NaN
# 17     17  3bb3b898-4b3c-4b57-8892-c3e00a631a34        CHW       54989   NaN
# 18     18  0ca139b7-4e99-4aa0-beb4-b29d98b76371        TUN       54990   NaN
# 19     19  b81377cf-febb-47a3-a94e-373fbf32715f        WAH       54991   NaN
# 20     20  96c550e5-6072-456e-86cb-dc38b2991776        ANW       54992   NaN
# 21     21  658f2ce2-86df-44d9-a2fe-8d1561052d37        DIA       54993   NaN
# 22     22  c9370911-57ff-4b01-93aa-1acad9d2d176        VAS       54994   NaN
# 23     23  8a9155b0-8816-4506-8ad2-a2140528b0a1        SIN       54995   NaN
# 24     24  0c6ea0a5-c297-4e54-bf76-db7428d0828f        ALV       54996   NaN
# 25     25  1cab170c-d954-4f55-90cc-3e0893ef6b6d        VIR       54997   NaN
# 26     26  fe1f1ac3-c326-4ac3-b84f-41fe0d378079        SAC       54998   NaN
# 27     27  5e4a9ce2-2cc8-4a13-bb34-6c7d7f84c1cc        PUL       54999   NaN
#
#    _record_name hasfootage
# 0            33        NaN
# 1            69        NaN
# 2             1        NaN
# 3             8        NaN
# 4            18        NaN
# 5            16        NaN
# 6            55        NaN
# 7             5        NaN
# 8            13        NaN
# 9             9        NaN
# 10           20       true
# 11           21       true
# 12           22       true
# 13           23       true
# 14           24       true
# 15           25       true
# 16           26        NaN
# 17           27        NaN
# 18           28        NaN
# 19           29        NaN
# 20           30        NaN
# 21           31        NaN
# 22           32        NaN
# 23           34        NaN
# 24           35        NaN
# 25           36        NaN
# 26           37        NaN
# 27           38        NaN

# %%
len(df_rosterEntry), len(df_car), len(df_biog), len(df_team)
# Out:
# (28, 28, 56, 28)

# %%
# Note that the official driver code may not be unique
df_car.iloc[1]
# Out:
# id                                                 NaN
# driverid                                           NaN
# driver                                       Rovanperä
# codriverid                                         NaN
# codriver                                     Halttunen
# teamid                                             NaN
# team                                               NaN
# teamseason                                         NaN
# category                                           WRC
# car                                                NaN
# carnumber                                          NaN
# isrelevant                                           1
# formerlastname                                     NaN
# fiasn
# _record_name                                 Rovanperä
# _rosterentryID    af059b41-d4b2-4484-8844-3991a0f3c846
# fiasn_gb                                           NaN
# filename                                           NaN
# hasfootage                                         NaN
# driverCode                                         ROV
# seasonname                                Toyota Gazoo
# Name: 1, dtype: object

# %%
df_team#.iloc[0]
# Out:
# Team                                                      seasonname teamid  \
# f547bbbc-f5fe-473f-b4ab-08f7e5cfe7e6                    Toyota Gazoo      4
# f547bbbc-f5fe-473f-b4ab-08f7e5cfe7e6                    Toyota Gazoo      4
# 2a336b8a-bb56-48cd-b5c2-f9e7c06bdaaf  Hyundai Shell World Rally Team     10
# 2a336b8a-bb56-48cd-b5c2-f9e7c06bdaaf  Hyundai Shell World Rally Team     10
# f547bbbc-f5fe-473f-b4ab-08f7e5cfe7e6                    Toyota Gazoo      4
# 2a336b8a-bb56-48cd-b5c2-f9e7c06bdaaf  Hyundai Shell World Rally Team     10
# 4bcee8a5-e595-4612-9162-15fc625a4758        M-Sport World Rally Team      4
# f547bbbc-f5fe-473f-b4ab-08f7e5cfe7e6                    Toyota Gazoo      4
# 4bcee8a5-e595-4612-9162-15fc625a4758        M-Sport World Rally Team      4
# 4bcee8a5-e595-4612-9162-15fc625a4758        M-Sport World Rally Team      4
# b47af8fe-b6f2-4df6-88e6-4369c64c6117                             NaN    NaN
# 5f8361c2-93a8-4ada-beb3-ef9b66d07024                             NaN    NaN
# 5f8361c2-93a8-4ada-beb3-ef9b66d07
# fd343670-c7ed-4ecf-b18d-b07b5f8d0e0c  08b8aefc-402a-4412-b639-3c5d349efdaf
# 5f8361c2-93a8-4ada-beb3-ef9b66d07024  bb14bf77-074e-4e27-a1aa-e45602c67bb9
# a08b008e-8d3c-4b40-8695-522876c9b5b3  ea768ec9-5cc2-45cf-82cb-311bce5fc976
# 6704a879-09ce-4be6-a851-d1962a6d8beb  22c934fb-74fa-417c-b261-bfccc42bc504
# 4527877f-ce12-420d-956f-4de057a29eec  adfb6d7a-6705-44fc-ac78-3bf2af54a005
# fd343670-c7ed-4ecf-b18d-b07b5f8d0e0c  0642d8c2-b8a5-4f95-8711-17bb74a9e159

# %%
df_biog.head(2)
# Out:
# Driver                                 id firstname middlename lastname  \
# b668b1a3-15f8-4494-8ce0-0e7efcae7278  547     Elfyn               Evans
# ea234420-58ef-4c8c-8d32-17a1b7ba8240  NaN     Scott        NaN   Martin
#
# Driver                               gender    birthday  age  \
# b668b1a3-15f8-4494-8ce0-0e7efcae7278      M  1988-12-28   25
# ea234420-58ef-4c8c-8d32-17a1b7ba8240      M         NaN  NaN
#
# Driver                                      birthplace nation       death  \
# b668b1a3-15f8-4494-8ce0-0e7efcae7278  Dolgellau, Wales    GBR  0000-00-00
# ea234420-58ef-4c8c-8d32-17a1b7ba8240               NaN    GBR         NaN
#
# Driver                                ... isindependent description hobbies  \
# b668b1a3-15f8-4494-8ce0-0e7efcae7278  ...           NaN         NaN     NaN
# ea234420-58ef-4c8c-8d32-17a1b7ba8240  ...           NaN         NaN     NaN
#
# Driver                               favouritedish favouritedrink  \
# b668b1a3-15f8-4494-8ce0-0e7efcae7278           NaN            NaN
# ea234420-58ef-4c8c-8d32-17a1b7ba8240           NaN            NaN
#
# Driver                               favouritesong characteristics sports  \
# b668b1a3-15f8-4494-8ce0-0e7efcae7278           NaN             NaN    NaN
# ea234420-58ef-4c8c-8d32-17a1b7ba8240           NaN             NaN    NaN
#
# Driver                               quotation aims
# b668b1a3-15f8-4494-8ce0-0e7efcae7278       NaN  NaN
# ea234420-58ef-4c8c-8d32-17a1b7ba8240       NaN  NaN
#
# [2 rows x 78 columns]

# %%
df_rallydata = wrc.process_rally_data(
    wrc.get_rallies_data(2025), rallyname="Safari Rally Kenya", year=2025
)
df_rallydata.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webappsdata.wrc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Session                              name    nr start-time-control  \
# d2830436-6bbe-4da2-9ee2-47e715b20b8e  SS1  8536                SS1
# bf72af72-86b2-4823-866d-62afa416dd22  SS2  8537                SS2
# bf6db08e-bb61-4ff2-aa41-669dbda78a20  SS3  8538                SS3
# dea2d8b6-287a-45d4-ba50-9dcf69f78628  SS4  8539                SS4
# da8935de-db5d-40f1-a710-c3dfce030a47  SS5  8540                SS5
#
# Session                                             location distance status  \
# https://webappsdata.wrc.com/srv/wrc/json/api/wrcsrv/byId?id=%2248aba032-b4bd-4b06-91a6-37212ba4ac7e%22&maxdepth=4
#
# as
# {
# n: "telemetry",
# v: "/4e4a394e-7797-4396-953c-b702035466ea/ss21gre_telemetry_js/js"
# },

# %%
df_stagedata = wrc.process_stage_data(df_rallydata, name="SS3")
display(df_stagedata.columns)
display(df_stagedata.iloc[0]["telemetry"])
df_stagedata.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webappsdata.wrc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Index(['nr', 'telemetry', 'offset', 'time', 'racetime', 'position', 'sname',
#        'evid', 'evname', 'stid', 'stname', 'category', 'sid', '_record_name',
#        '_rally_stageid', '_carentryid'],
#       dtype='object', name='Entry')
# '/35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03mun_telemetry_js/js'
# Entry                                               nr  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  13
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  69
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  16
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...   5
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...   9
#
# Entry                                                                                       telemetry  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03mun_...
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03rov_...
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03paj_...
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03ser_...
#
# Entry                                                      offset  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  1742542800000
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  1742541360000
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  1742542260000
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  1742542620000
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  1742542980000
#
# Entry                                                              time  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  03/21/2025 07:40:00
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  03/21/2025 07:16:00
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  03/21/2025 07:31:00
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  03/21/2025 07:37:00
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  03/21/2025 07:43:00
#
# Entry                                              racetime position sname  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  1614700        7  2025
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  1582000        4  2025
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  1584900        5  2025
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  1761500       16  2025
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  1703500       14  2025
#
# Entry                                                                               evid  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  35c61a2f-46b2-41b7-8af9-a19ceea5583d
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  35c61a2f-46b2-41b7-8af9-a19ceea5583d
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  35c61a2f-46b2-41b7-8af9-a19ceea5583d
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  35c61a2f-46b2-41b7-8af9-a19ceea5583d
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  35c61a2f-46b2-41b7-8af9-a19ceea5583d
#
# Entry                                                           evname  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  Safari Rally Kenya
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  Safari Rally Kenya
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  Safari Rally Kenya
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  Safari Rally Kenya
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  Safari Rally Kenya
#
# Entry                                                                               stid  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#
# Entry                                              stname category  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...    SS3      WRC
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...    SS3      WRC
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...    SS3      WRC
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...    SS3      WRC
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...    SS3      WRC
#
# Entry                                                                                sid  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  9f219417-c137-4e53-8ea8-188bda577eca
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  9f219417-c137-4e53-8ea8-188bda577eca
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  9f219417-c137-4e53-8ea8-188bda577eca
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  9f219417-c137-4e53-8ea8-188bda577eca
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  9f219417-c137-4e53-8ea8-188bda577eca
#
# Entry                                              _record_name  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...      Munster
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...    Rovanpera
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...     Fourmaux
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...       Pajari
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...   Serderidis
#
# Entry                                                                     _rally_stageid  \
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#
# Entry                                                                        _carentryid
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-c...  27ec75b8-ca03-4d20-867e-de6aec1a433c
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9...  8cf73a6b-9199-4aa6-9954-635b124c1dd4
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2...  97209e11-2ea3-4327-be4b-bc7bde735a66
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-8...  5be9bf71-86b0-4270-b26e-34bd4e30cf09
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-3...  a061ea3b-327d-400c-8930-93844a964727

# %%
df_stagedata.columns
# Out:
# Index(['nr', 'telemetry', 'offset', 'time', 'racetime', 'position', 'sname',
#        'evid', 'evname', 'stid', 'stname', 'category', 'sid', '_record_name',
#        '_rally_stageid', '_carentryid'],
#       dtype='object', name='Entry')

# %%
df_stagedata["_record_name"]
# Out:
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_27ec75b8-ca03-4d20-867e-de6aec1a433c         Munster
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8cf73a6b-9199-4aa6-9954-635b124c1dd4       Rovanpera
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_97209e11-2ea3-4327-be4b-bc7bde735a66        Fourmaux
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_5be9bf71-86b0-4270-b26e-34bd4e30cf09          Pajari
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a061ea3b-327d-400c-8930-93844a964727      Serderidis
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_41aee8bb-a96d-43ae-a3bc-712c00c406fe         Katsuta
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_b185c5df-8115-40cf-bd81-566f016f6bf5           Evans
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_1caa9ae0-88a1-48ed-9106-2c302df1de75        Mcerlean
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_8a564d9e-56f4-4fec-9299-5d5af97b6797    Kajetanowicz
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_a7b1a919-5302-4168-81fb-c59177367c16        Zaldivar
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_f6bdb6cd-f2f5-4f92-bb7c-d9528462b153          Solans
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_1e6049d3-0b71-4ed0-8418-35274628f77c         Solberg
# bf6db08e-bb61-4ff2-aa41-669dbda78a20_b43804ea-3fd7-461d-9128-58588b915de0       Dominguez
# Name: _record_name, dtype: object

# %%
df_telemetrydata, df_telemetrymergeddata = wrc.process_driver_telemetry_data(
    df_stagedata,'Fourmaux' )
# Out:
# Checking telemetry...
# _rally_stage_id, _car_entry_id, _telemetryID, _telemetrymergedID
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webappsdata.wrc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
df_telemetrydata, df_telemetrymergeddata
# Out:
# (      accx  accy  altitude  brk driverid  gear  heading   kms      lat  \
#  0        0     0         0    0    85321     0      144  28.1 -0.49503
#  1        0     0         0    0    85321     0      144  28.1 -0.49503
#  2        0     0         0    0    85321     0      146  28.1 -0.49503
#  3        0     0         0    0    85321     0      148  28.1 -0.49503
#  4        0     0         0    0    85321     0      148  28.1 -0.49503
#  ...    ...   ...       ...  ...      ...   ...      ...   ...      ...
#  4160     0     0         0    0    85321     0      142   0.0 -0.55557
#  4161     0     0         0    0    85321     0      142   0.0 -0.55557
#  4162     0     0         0    0    85321     0      110   0.0 -0.55557
#  4163     0     0         0    0    85321     0      144   0.0 -0.55557
#  4164     0     0         0    0    85321     0      142   0.0 -0.55557
#
#             lon  ... rpm  speed     status throttle  track            utx  \
#  0     36.26853  ...   0      0  Competing        0         1742568152900
#  1     36.26853  ...   0      0  Competing        0         1742568149700
#  2     36.26853  ...   0      0  Competing        0         1742568146500
#  3     36.26853  ...   0      0  Competing        0         1742568143300
#  4     36.26853  ...   0      0  Competing        0         1742568140100
#  ...        ...  ...  ..    ...        ...      ...    ...            ...
#  4160  36.27961  ...   0      0  Competing        0         1742542050400
#  4161  36.27961  ...   0      0  Competing        0         1742542044000
#  4162  36.27961  ...   0      0  Competing        0         1742542037600
#  4163  36.27961  ...   0      0  Competing        0         1742542031200
#  4164  36.27961  ...   0      0  Competing        0         1742542024800
#
#                              _rally_stageid  \
#  0     bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  1     bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  2     bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  3     bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  4     bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  ...                                    ...
#  4160  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  4161  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  4162  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  4163  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#  4164  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#
#                                 _carentryid  \
#  0     97209e11-2ea3-4327-be4b-bc7bde735a66
#  1     97209e11-2ea3-4327-be4b-bc7bde735a66
#  2     97209e11-2ea3-4327-be4b-bc7bde735a66
#  3     97209e11-2ea3-4327-be4b-bc7bde735a66
#  4     97209e11-2ea3-4327-be4b-bc7bde735a66
#  ...                                    ...
#  4160  97209e11-2ea3-4327-be4b-bc7bde735a66
#  4161  97209e11-2ea3-4327-be4b-bc7bde735a66
#  4162  97209e11-2ea3-4327-be4b-bc7bde735a66
#  4163  97209e11-2ea3-4327-be4b-bc7bde735a66
#  4164  97209e11-2ea3-4327-be4b-bc7bde735a66
#
#                                             _telemetryID     _name
#  0     /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  1     /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  2     /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  3     /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  4     /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  ...                                                 ...       ...
#  4160  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  4161  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  4162  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  4163  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#  4164  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#
#  [4165 rows x 21 columns],
#  Empty DataFrame
#  Columns: []
#  Index: [])

# %%
r = wrc.get_rallies_data(2025, as_dict=True)[0]
# SASEVENTID = 534 ; sas-rallyid: 582
# http://www.wrc.com/service/sasCacheApi.php?route=events/{SASEVENTID}
# rallies/{rallyId}/stagewinners
# FOLLOWING NO LONGER WORKS AT WRC?
# https://www.wrc.com/service/sasCacheApi.php?route=events/534/rallies/582/stagewinners
r
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webappsdata.wrc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'sas-eventid': '534',
#  'name': 'Rallye Monte-Carlo',
#  'sitid': '534',
#  'sas-rallyid': '582',
#  'sas-itineraryid': '1119',
#  'sas-trackingid': '4208',
#  'date-start': '2025-01-23',
#  'date-finish': '2025-01-26',
#  'info-date': '23 - 26 Jan 25',
#  'info-based': 'Gap, France',
#  'info-surface': 'Mixed',
#  'info-flag': 'MON',
#  'info-website': 'https://acm.mc/',
#  'tzoffset': '0',
#  'category': 'WRC',
#  'position': '7.421630,43.734607',
#  'poilistid': '0bcfbf8d-0e67-4249-aa5c-65799adcd356',
#  'logo': 'images/montecarlo_2024.png',
#  'kmlfile': 'montecarlo_2025',
#  'rosterid': '00ddf31e-4c18-4e13-8ded-f62f3f84c684',
#  'aws_folder': 'pimuc',
#  'availability': 'now',
#  'hasvideos': 'true',
#  '_record_name': 'Rallye Monte-Carlo 2025',
#  'year': '2025',
#  'awsfolder': nan}

# %%
# from shinywidgets import render_widget
# import geopandas as gpd

# from io import StringIO
# from ipyleaflet import Map, Marker, GeoData, GeoJSON

geostages = wrc.read_kmlfile(r["kmlfile"])
# boundaries = wrc.kmlfile_to_json(r['kmlfile'])

geostages
# gpd.GeoDataFrame.from_features(boundaries[0]["features"])
# g = gpd.GeoDataFrame(wrc.get_map_stages(boundaries))
# gpd.geopandas.read_file(StringIO(str(boundaries[0])))
# Out:
#          name        stages                                      start  \
# 0   Shakedown   [Shakedown]  (6.042704031930801, 44.559764250197, 0.0)
# 1     SS 1/17   [SS1, SS17]  (6.264440450040201, 44.079301943751, 0.0)
# 2        SS 2         [SS2]    (6.0922598157795, 44.397960224215, 0.0)
# 3     SS 3/16   [SS3, SS16]    (6.1720265993721, 44.544598578142, 0.0)
# 4      SS 4/7    [SS4, SS7]    (6.0964818131896, 44.804749895108, 0.0)
# 5      SS 5-8    [SS5, SS8]        (6.196878999999999, 44.643949, 0.0)
# 6      SS 6-9    [SS6, SS9]                  (6.304178, 44.44236, 0.0)
# 7    SS 10/13  [SS10, SS13]    (5.3765337292667, 44.489641114902, 0.0)
# 8    SS 11/14  [SS11, SS14]    (5.3448707617935, 44.624669030287, 0.0)
# 9    SS 12/15  [SS12, SS15]    (5.6383926910448, 44.513366884411, 0.0)
# 10      SS 18        [SS18]  (7.331929681299101, 43.990417203574, 0.0)
#
#                                      finish  \
# 0   (6.0298841750004, 44.552857040276, 0.0)
# 1   (6.3100331508213, 43.982811558069, 0.0)
# 2   (6.2008078801752, 44.420944555289, 0.0)
# 3   (6.1495851364962, 44.517940317982, 0.0)
# 4   (6.0464240165479, 44.723124414211, 0.0)
# 5    (6.2212989177526, 44.57199506402, 0.0)
# 6    (6.308830381763, 44.372790086613, 0.0)
# 7   (5.2853453372715, 44.569941285717, 0.0)
# 8    (5.4074679393438, 44.64753343844, 0.0)
# 9   (5.7221531497862, 44.485567512913, 0.0)
# 10  (7.3661662453594, 43.944437668643, 0.0)
#
#                                              geometry
# 0   LINESTRING Z (6.0427 44.55976 0, 6.04258 44.55...
# 1   LINESTRING Z (6.26444 44.0793 0, 6.26483 44.07...
# 2   LINESTRING Z (6.09226 44.39796 0, 6.09239 44.3...
# 3   LINESTRING Z (6.17203 44.5446 0, 6.17176 44.54...
# 4   LINESTRING Z (6.09648 44.80475 0, 6.09661 44.8...
# 5   LINESTRING Z (6.19688 44.64395 0, 6.19691 44.6...
# 6   LINESTRING Z (6.30418 44.44236 0, 6.3039 44.44...
# 7   LINESTRING Z (5.37653 44.48964 0, 5.37648 44.4...
# 8   LINESTRING Z (5.34487 44.62467 0, 5.34494 44.6...
# 9   LINESTRING Z (5.63839 44.51337 0, 5.63837 44.5...
# 10  LINESTRING Z (7.33193 43.99042 0, 7.33196 43.9...

# %%
poi_df = wrc.get_poilist_data(r["poilistid"])

poi_df
# Out:
#         type                  name                                   _id  \
# 0   POIEntry               MCO SS1  fad72d32-ea44-44d7-a2ea-25f6c5a70a52
# 1   POIEntry               MCO SS2  402df5d2-a709-4469-9c8b-04c9a2a83090
# 2   POIEntry               MCO SS3  63a7d8ec-cdf3-4746-b128-437b98164bab
# 3   POIEntry               MCO SS4  3f2a8511-e3d5-4726-93e6-3209371573b8
# 4   POIEntry               MCO SS5  0da1e8c5-a128-48de-b089-531ca3aaa4c9
# 5   POIEntry               MCO SS6  982abe0c-8f1f-4a6e-aeb8-ce3a563ae22d
# 6   POIEntry               MCO SS7  aa62e6de-dd40-47af-a460-ab281d1d8eac
# 7   POIEntry               MCO SS8  ef9daa58-23f6-4820-bd8c-606de6b9babd
# 8   POIEntry               MCO SS9  c55eb2e1-823d-441f-80e5-a7432e7c4e9f
# 9   POIEntry              MCO SS10  4981ab97-6d33-40e5-a902-b74b7c630aa3
# 10  POIEntry              MCO SS11  e9ac6aaf-98c9-4ad1-88da-5388cc1cdad3
# 11  POIEntry              MCO SS12  a4f62db7-4a8a-4ca2-bc03-9aaea2490147
# 12  POIEntry              MCO SS13  7c140155-c9fd-4988-a1d4-3a3a854e744e
# 13  POIEntry              MCO SS14  82dd7b83-68df-436e-bd7f-73b8b285f31d
# 14  POIEntry              MCO SS15  50c2a4ca-4f0d-4c96-9b88-007f356f3488
# 15  POIEntry              MCO SS16  030fe797-80ce-4935-8371-4cd5e9a23e55
# 16  POIEntry              MCO SS17  7d60d1da-11d9-4acb-b941-6e1866d547f1
# 17  POIEntry              MCO SS18  90936b71-7e11-46e3-b0eb-30ee82408001
# 19  POIEntry  mon Service Park Gap  fb3412a1-b874-4724-a2c4-9e1b05eef91a
# 20  POIEntry             Shakedown  545844dc-baa1-45cf-9e80-a6d2ae2feed0
#
#    desription            icon  \
# 0         SS1
# 1         SS2
# 2         SS3
# 3         SS4
# 4         SS5
# 5         SS6
# 6         SS7
# 7         SS8
# 8         SS9
# 9        SS10
# 10       SS11
# 11       SS12
# 12       SS13
# 13       SS14
# 14       SS15
# 15       SS16
# 16       SS17
# 17       SS18
# 19        NaN  images/red.png
# 20        NaN  images/red.png
#
#                                                 label minscale moveto  \
# 0   Stage 1<br/>Digne-les<br/>Bains <br/> Chaudon ...     11.5   true
# 1           Stage 2<br/>Faucon-du<br/>Caire  Bréziers     11.5   true
# 2   Stage 3<br/>Avançon <br/> Notre<br/>Dame du La...     11.5   true
# 3        Stage 4<br/>Saint-Maurice <br/> Aubessagne 1     11.5   true
# 4   Stage 5<br/>Saint-Léger<br/>les<br/>Mélèzes <b...     11.5   true
# 5              Stage 6<br/>La Bréole <br/> Selonnet 1     11.5   true
# 6        Stage 7<br/>Saint-Maurice <br/> Aubessagne 2     11.5   true
# 7   Stage 8<br/>Saint-Léger<br/>les<br/>Mélèzes <b...     11.5   true
# 8              Stage 9<br/>La Bréole <br/> Selonnet 2     11.5   true
# 9   Stage 10<br/>La Motte<br/>Chalancon <br/> Sain...     11.5   true
# 10  Stage 11<br/>Aucelon <br/> Recoubeau<br/>Jansac 1     11.5   true
# 11  Stage 12<br/>La-Bâtie<br/>des Fonts <br/> Aspr...     11.5   true
# 12  Stage 13<br/>La Motte<br/>Chalancon <br/> Sain...     11.5   true
# 13  Stage 14<br/>Aucelon <br/> Recoubeau<br/>Jansac 2     11.5   true
# 14  Stage 15<br/>La-Bâtie<br/>des Fonts <br/> Aspr...     11.5   true
# 15  Stage 16<br/>Avançon <br/> Notre<br/>Dame du L...     11.5   true
# 16  Stage 17<br/>Digne-les<br/>Bains <br/> Chaudon...     11.5   true
# 17  Stage 18<br/>La Bollène<br/>Vésubie <br/> Peïr...     11.5   true
# 19                                 GAP - SERVICE PARK      8.1   true
# 20                                          shakedown      8.1   true
#
#    noperspective                               position  \
# 0           true      44.0235264160032,6.24765960491581
# 1           true   44.389767890030654,6.134377784197341
# 2           true    44.52457227330618,6.158553406752532
# 3           true    44.74844224996965,6.074560220840226
# 4           true    44.613439746019516,6.18621021100148
# 5           true  44.422388208445476,6.2810480171612255
# 6           true    44.74826264227178,6.074337365360435
# 7           true   44.613585081586955,6.186021726167098
# 8           true    44.42250500890244,6.281028867612605
# 9           true     44.5477055853812,5.329780580007537
# 10          true   44.63499658464293,5.3202204222240255
# 11          true    44.50933822188107,5.682908876584179
# 12          true   44.547815488051725,5.329638979479995
# 13          true   44.635059091176934,5.320132564461659
# 14          true   44.509510559356315,5.682987635441094
# 15          true    44.52447910837573,6.158543181694711
# 16          true   44.023564336541064,6.248105572758789
# 17          true    43.968536718109526,7.34967571439617
# 19          true                    44.540958, 6.060461
# 20          true    44.55140595091118,6.042084583556544
#
#                                  stageid type_meta       description  \
# 0   31c5b6aa-7741-464c-8cfd-3c5b805476f9     point               NaN
# 1   5ff95de1-04c7-4146-9a45-3d10ea5702ce     point               NaN
# 2   449931bd-9833-4a2d-87d2-f8da247a0844     point               NaN
# 3   0c6abba6-0590-4f7c-8dc1-43005ebf5eea     point               NaN
# 4   dbde25be-98bf-4643-b6a0-6dfcee4698aa     point               NaN
# 5   ead2621c-b23e-436a-b910-7de42a0229f4     point               NaN
# 6   cb80eace-5997-4349-815b-566b64be2b52     point               NaN
# 7   280d94b2-51d2-48e7-915a-8211d6c3e236     point               NaN
# 8   1d244af8-6baf-48bc-aeb6-8f9c065aa18c     point               NaN
# 9   5694d0ee-cf3a-4eb9-8596-be1f95aa8068     point               NaN
# 10  564e98ec-0add-4e89-bb88-5225336237ad     point               NaN
# 11  afcaa5eb-ec0d-4faa-af98-46e355bf7c22     point               NaN
# 12  dde36da0-5ebb-41e4-8b63-eec1d76ca525     point               NaN
# 13  ef25ee26-b84c-4ad7-949d-9b5405d3bb01     point               NaN
# 14  6af2a0fc-a2e0-4538-a984-e960f19af36f     point               NaN
# 15  26ac70e4-f938-4449-8240-fa5c03959d0c     point               NaN
# 16  9b5932e2-fb57-4063-86ca-b7cc6bea9573     point               NaN
# 17  0e26b734-6533-47bc-8521-80a4640745c1     point               NaN
# 19                                   NaN     point  Service Park Gap
# 20                                   NaN     point   mon24 Shakedown
#
#    iconwidth  name_meta   latitude  longitude
# 0        NaN        NaN  44.023526   6.247660
# 1        NaN        NaN  44.389768   6.134378
# 2        NaN        NaN  44.524572   6.158553
# 3        NaN        NaN  44.748442   6.074560
# 4        NaN        NaN  44.613440   6.186210
# 5        NaN        NaN  44.422388   6.281048
# 6        NaN        NaN  44.748263   6.074337
# 7        NaN        NaN  44.613585   6.186022
# 8        NaN        NaN  44.422505   6.281029
# 9        NaN        NaN  44.547706   5.329781
# 10       NaN        NaN  44.634997   5.320220
# 11       NaN        NaN  44.509338   5.682909
# 12       NaN        NaN  44.547815   5.329639
# 13       NaN        NaN  44.635059   5.320133
# 14       NaN        NaN  44.509511   5.682988
# 15       NaN        NaN  44.524479   6.158543
# 16       NaN        NaN  44.023564   6.248106
# 17       NaN        NaN  43.968537   7.349676
# 19         5        NaN  44.540958   6.060461
# 20         5  Shakedown  44.551406   6.042085

# %%
# Twrc.GeoTools.simple_stage_map(geostages, ["SS7", "SS5"])

# %%
poi_df
# Out:
#         type                  name                                   _id  \
# 0   POIEntry               MCO SS1  fad72d32-ea44-44d7-a2ea-25f6c5a70a52
# 1   POIEntry               MCO SS2  402df5d2-a709-4469-9c8b-04c9a2a83090
# 2   POIEntry               MCO SS3  63a7d8ec-cdf3-4746-b128-437b98164bab
# 3   POIEntry               MCO SS4  3f2a8511-e3d5-4726-93e6-3209371573b8
# 4   POIEntry               MCO SS5  0da1e8c5-a128-48de-b089-531ca3aaa4c9
# 5   POIEntry               MCO SS6  982abe0c-8f1f-4a6e-aeb8-ce3a563ae22d
# 6   POIEntry               MCO SS7  aa62e6de-dd40-47af-a460-ab281d1d8eac
# 7   POIEntry               MCO SS8  ef9daa58-23f6-4820-bd8c-606de6b9babd
# 8   POIEntry               MCO SS9  c55eb2e1-823d-441f-80e5-a7432e7c4e9f
# 9   POIEntry              MCO SS10  4981ab97-6d33-40e5-a902-b74b7c630aa3
# 10  POIEntry              MCO SS11  e9ac6aaf-98c9-4ad1-88da-5388cc1cdad3
# 11  POIEntry              MCO SS12  a4f62db7-4a8a-4ca2-bc03-9aaea2490147
# 12  POIEntry              MCO SS13  7c140155-c9fd-4988-a1d4-3a3a854e744e
# 13  POIEntry              MCO SS14  82dd7b83-68df-436e-bd7f-73b8b285f31d
# 14  POIEntry              MCO SS15  50c2a4ca-4f0d-4c96-9b88-007f356f3488
# 15  POIEntry              MCO SS16  030fe797-80ce-4935-8371-4cd5e9a23e55
# 16  POIEntry              MCO SS17  7d60d1da-11d9-4acb-b941-6e1866d547f1
# 17  POIEntry              MCO SS18  90936b71-7e11-46e3-b0eb-30ee82408001
# 19  POIEntry  mon Service Park Gap  fb3412a1-b874-4724-a2c4-9e1b05eef91a
# 20  POIEntry             Shakedown  545844dc-baa1-45cf-9e80-a6d2ae2feed0
#
#    desription            icon  \
# 0         SS1
# 1         SS2
# 2         SS3
# 3         SS4
# 4         SS5
# 5         SS6
# 6         SS7
# 7         SS8
# 8         SS9
# 9        SS10
# 10       SS11
# 11       SS12
# 12       SS13
# 13       SS14
# 14       SS15
# 15       SS16
# 16       SS17
# 17       SS18
# 19        NaN  images/red.png
# 20        NaN  images/red.png
#
#                                                 label minscale moveto  \
# 0   Stage 1<br/>Digne-les<br/>Bains <br/> Chaudon ...     11.5   true
# 1           Stage 2<br/>Faucon-du<br/>Caire  Bréziers     11.5   true
# 2   Stage 3<br/>Avançon <br/> Notre<br/>Dame du La...     11.5   true
# 3        Stage 4<br/>Saint-Maurice <br/> Aubessagne 1     11.5   true
# 4   Stage 5<br/>Saint-Léger<br/>les<br/>Mélèzes <b...     11.5   true
# 5              Stage 6<br/>La Bréole <br/> Selonnet 1     11.5   true
# 6        Stage 7<br/>Saint-Maurice <br/> Aubessagne 2     11.5   true
# 7   Stage 8<br/>Saint-Léger<br/>les<br/>Mélèzes <b...     11.5   true
# 8              Stage 9<br/>La Bréole <br/> Selonnet 2     11.5   true
# 9   Stage 10<br/>La Motte<br/>Chalancon <br/> Sain...     11.5   true
# 10  Stage 11<br/>Aucelon <br/> Recoubeau<br/>Jansac 1     11.5   true
# 11  Stage 12<br/>La-Bâtie<br/>des Fonts <br/> Aspr...     11.5   true
# 12  Stage 13<br/>La Motte<br/>Chalancon <br/> Sain...     11.5   true
# 13  Stage 14<br/>Aucelon <br/> Recoubeau<br/>Jansac 2     11.5   true
# 14  Stage 15<br/>La-Bâtie<br/>des Fonts <br/> Aspr...     11.5   true
# 15  Stage 16<br/>Avançon <br/> Notre<br/>Dame du L...     11.5   true
# 16  Stage 17<br/>Digne-les<br/>Bains <br/> Chaudon...     11.5   true
# 17  Stage 18<br/>La Bollène<br/>Vésubie <br/> Peïr...     11.5   true
# 19                                 GAP - SERVICE PARK      8.1   true
# 20                                          shakedown      8.1   true
#
#    noperspective                               position  \
# 0           true      44.0235264160032,6.24765960491581
# 1           true   44.389767890030654,6.134377784197341
# 2           true    44.52457227330618,6.158553406752532
# 3           true    44.74844224996965,6.074560220840226
# 4           true    44.613439746019516,6.18621021100148
# 5           true  44.422388208445476,6.2810480171612255
# 6           true    44.74826264227178,6.074337365360435
# 7           true   44.613585081586955,6.186021726167098
# 8           true    44.42250500890244,6.281028867612605
# 9           true     44.5477055853812,5.329780580007537
# 10          true   44.63499658464293,5.3202204222240255
# 11          true    44.50933822188107,5.682908876584179
# 12          true   44.547815488051725,5.329638979479995
# 13          true   44.635059091176934,5.320132564461659
# 14          true   44.509510559356315,5.682987635441094
# 15          true    44.52447910837573,6.158543181694711
# 16          true   44.023564336541064,6.248105572758789
# 17          true    43.968536718109526,7.34967571439617
# 19          true                    44.540958, 6.060461
# 20          true    44.55140595091118,6.042084583556544
#
#                                  stageid type_meta       description  \
# 0   31c5b6aa-7741-464c-8cfd-3c5b805476f9     point               NaN
# 1   5ff95de1-04c7-4146-9a45-3d10ea5702ce     point               NaN
# 2   449931bd-9833-4a2d-87d2-f8da247a0844     point               NaN
# 3   0c6abba6-0590-4f7c-8dc1-43005ebf5eea     point               NaN
# 4   dbde25be-98bf-4643-b6a0-6dfcee4698aa     point               NaN
# 5   ead2621c-b23e-436a-b910-7de42a0229f4     point               NaN
# 6   cb80eace-5997-4349-815b-566b64be2b52     point               NaN
# 7   280d94b2-51d2-48e7-915a-8211d6c3e236     point               NaN
# 8   1d244af8-6baf-48bc-aeb6-8f9c065aa18c     point               NaN
# 9   5694d0ee-cf3a-4eb9-8596-be1f95aa8068     point               NaN
# 10  564e98ec-0add-4e89-bb88-5225336237ad     point               NaN
# 11  afcaa5eb-ec0d-4faa-af98-46e355bf7c22     point               NaN
# 12  dde36da0-5ebb-41e4-8b63-eec1d76ca525     point               NaN
# 13  ef25ee26-b84c-4ad7-949d-9b5405d3bb01     point               NaN
# 14  6af2a0fc-a2e0-4538-a984-e960f19af36f     point               NaN
# 15  26ac70e4-f938-4449-8240-fa5c03959d0c     point               NaN
# 16  9b5932e2-fb57-4063-86ca-b7cc6bea9573     point               NaN
# 17  0e26b734-6533-47bc-8521-80a4640745c1     point               NaN
# 19                                   NaN     point  Service Park Gap
# 20                                   NaN     point   mon24 Shakedown
#
#    iconwidth  name_meta   latitude  longitude
# 0        NaN        NaN  44.023526   6.247660
# 1        NaN        NaN  44.389768   6.134378
# 2        NaN        NaN  44.524572   6.158553
# 3        NaN        NaN  44.748442   6.074560
# 4        NaN        NaN  44.613440   6.186210
# 5        NaN        NaN  44.422388   6.281048
# 6        NaN        NaN  44.748263   6.074337
# 7        NaN        NaN  44.613585   6.186022
# 8        NaN        NaN  44.422505   6.281029
# 9        NaN        NaN  44.547706   5.329781
# 10       NaN        NaN  44.634997   5.320220
# 11       NaN        NaN  44.509338   5.682909
# 12       NaN        NaN  44.547815   5.329639
# 13       NaN        NaN  44.635059   5.320133
# 14       NaN        NaN  44.509511   5.682988
# 15       NaN        NaN  44.524479   6.158543
# 16       NaN        NaN  44.023564   6.248106
# 17       NaN        NaN  43.968537   7.349676
# 19         5        NaN  44.540958   6.060461
# 20         5  Shakedown  44.551406   6.042085

# %%
# TO DO - a simple plot with json data ?
wrc.GeoTools.simple_stage_map(geostages,stages="SS1")
# Out:
# Map(center=[np.float64(44.0312982731875), np.float64(6.2997171821242)], controls=(ZoomControl(options=['positi…

# %%
wrc.GeoTools.simple_stage_map(geostages,["SS1", "SS13"])
# Out:
# Map(center=[np.float64(44.276376421893005), np.float64(5.808491041109599)], controls=(ZoomControl(options=['po…

# %% [markdown]
# Geo ipynb notebook with examples:
#
# https://github.com/innovationOUtside/wrcplus/blob/master/notebooks/Map%20KML%20etc.ipynb

# %%
# Length of line
print(
    geostages["geometry"].iloc[2].length
)  

# Example plot - renders natively in notebook
geostages["geometry"].iloc[2]

# matplotlib plot all stages:
# geostages["geometry"].plot()
# Out:
# 0.2350694871504342
# <LINESTRING Z (6.092 44.398 0, 6.092 44.398 0, 6.092 44.398 0, 6.093 44.398 ...>

# %%
type(geostages["geometry"].iloc[0])
# Out:
# shapely.geometry.linestring.LineString

# %%
display(geostages["geometry"].iloc[2])
display(wrc.GeoTools.cut_line_by_distance_meters(geostages["geometry"].iloc[2],8000, 12000))
# display(cut(geostages["geometry"].iloc[2], 0.05)[1])
# Out:
# <LINESTRING Z (6.092 44.398 0, 6.092 44.398 0, 6.092 44.398 0, 6.093 44.398 ...>
# <LINESTRING (6.169 44.418, 6.168 44.417, 6.168 44.417, 6.168 44.417, 6.168 4...>

# %%
# Highlight a segment in the context of the preceding and following segments
# This is not done to a km/m scale. We would need to
# transform the latlong co-ords first to do that
# to get eg 100m either side of a 100m stretch
import matplotlib.pyplot as plt
from shapely.geometry import LineString, Point
import geopandas as gpd

# http://toblerity.org/shapely/manual.html?highlight=cut
# The cut function will find a distance along a line and then cut it at a nearby vertex
def cut(line, distance):
    """Cut a line into two separate lines at a specified distance from its starting point."""
    if distance <= 0.0 or distance >= line.length:
        return [LineString(line)]
    coords = list(line.coords)
    # Patch out the z co-ord
    coords = [(c[0], c[1]) for c in coords]
    for i, p in enumerate(coords):
        pd = line.project(Point(p))
        if pd == distance:
            return [LineString(coords[: i + 1]), LineString(coords[i:])]
        if pd > distance:
            cp = line.interpolate(distance)
            return [
                LineString(coords[:i] + [(cp.x, cp.y)]),
                LineString([(cp.x, cp.y)] + coords[i:]),
            ]

# ALSO the following accepts diatances in meters
# wrc.GeoTools.cut_line_by_distance_meters(line, 1000, 2000)

def highlightline_segment(line, start, end):
    # TO DO this needs projecting into meters
    edgedsegment = cut(
        cut(line, start - 0.01)[1],
        end - start + 0.02,
    )[0]
    segments = cut(edgedsegment, 0.01)
    firstsegment = segments[0]
    segments = [firstsegment] + cut(segments[1], segments[1].length - 0.01)
    # Segments is a list of linestring objects
    # print(segments)
    # segments=cut(line,0.1)
    gdf_segments = gpd.GeoDataFrame(list(range(len(segments))), geometry=segments)
    gdf_segments.columns = ["index", "geometry"]

    return gdf_segments


line = geostages["geometry"].iloc[2]
print(line.length)
start = 0.05
end = 0.06
print(line)
gdf_segments = highlightline_segment(line, start, end)

fig, ax = plt.subplots()
# line.plot(ax=ax, lw=6, color='gray')
ax = gdf_segments.plot(ax=ax, lw=3, color=["lightgrey", "blue", "lightgrey"])
# Out:
# 0.2350694871504342
# LINESTRING Z (6.0922598157795 44.397960224215 0, 6.092386871335201 44.39797838039 0, 6.092485339390899 44.398014692722 0, 6.092580631057701 44.398077104492 0, 6.0927870963358 44.398293843028 0, 6.093280999999999 44.398981 0, 6.093552106116 44.399382175229 0, 6.0937538197717 44.399797740966 0, 6.0938407661699 44.399940408895 0, 6.0939384996402 44.400066865982 0, 6.0940160060131 44.400149760236 0, 6.094300981413101 44.400480995813 0, 6.0943876257427 44.400549863568 0, 6.0945458370642 44.400638794347 0, 6.095610299453501 44.401055568468 0, 6.0958074116176 44.401137084398 0, 6.0960925182026 44.40132372108 0, 6.0963310655986 44.401552672427 0, 6.096447399201 44.401714741247 0, 6.096839927819299 44.402394803574 0, 6.0970339247598 44.402611157721 0, 6.098067128336699 44.403503281214 0, 6.0984303555056 44.403685119178 0, 6.098738561124 44.403849073068 0, 6.0991064939953 44.40413977336 0, 6.0999704184082 44.404936471402 0, 6.1013518818597 44.405704294982 0, 6.1022253409661 44.406158511922 0, 6.1025002417008 44.406289392124 0, 6.1032088015553 44.406511905937 0, 6.103721 44.406781 0, 6.1043649306182 44.407194091909 0, 6.1046279433156 44.407367457802 0, 6.104901000000001 44.407468 0, 6.105952 44.40772 0, 6.1065826787128 44.407759662
6.133713 44.419688 0, 6.133761 44.419811 0, 6.134437 44.420031 0, 6.134501999999999 44.42009 0, 6.134427 44.420342 0, 6.134437 44.420434 0, 6.134560999999999 44.420519 0, 6.135230999999999 44.420691 0, 6.135676 44.420519 0, 6.135913 44.420455 0, 6.13617 44.420487 0, 6.136513 44.420755 0, 6.1366868273768 44.420826676883 0, 6.137044 44.420911 0, 6.137457 44.421061 0, 6.138325999999999 44.421158 0, 6.139002 44.42127 0, 6.139700000000001 44.421474 0, 6.140075 44.421764 0, 6.140215 44.422129 0, 6.140292771482101 44.422197769012 0, 6.140419 44.422247 0, 6.140612000000001 44.422252 0, 6.1408873067897 44.422167612489 0, 6.1409402575966 44.422149773372 0, 6.1411588922952 44.422050520813 0, 6.141679702176299 44.421705484878 0, 6.1421318855701 44.42140639966 0, 6.1424809023067 44.421199841708 0, 6.1425731764973 44.421149903179 0, 6.142738151667199 44.421086898604 0, 6.1429419992159 44.42105771024 0, 6.1431438842166 44.421068185365 0, 6.1439908964129 44.421156020223 0, 6.1446471162341 44.421204617054 0, 6.145526 44.421303 0, 6.146361999999999 44.421152 0, 6.14707 44.420938 0, 6.147397999999999 44.420863 0, 6.147661 44.420873 0, 6.147746 44.420911 0, 6.147827000000001 44.421008 0, 6.147934 44.421372 0, 6.147999 44.421485 0, 6.14824 44.421614 0, 6.148727999999999 44.421651 0, 6.148948 44.421614 0, 6.149179 44.42149 0, 6.149329 44.421136 0, 6.149447 44.420696 0, 6.149489999999999 44.420621 0, 6.15075 44.420122 0, 6.151287000000001 44.419913 0, 6.151378000000001 44.41987 0, 6.152113 44.419624 0, 6.1527306466501 44.419472302614 0, 6.1540496674304 44.419248072283 ...

# %%
gdf_segments
# Out:
#    index                                           geometry
# 0      0  LINESTRING (6.09226 44.39796, 6.09239 44.39798...
# 1      1  LINESTRING (6.16796 44.40871, 6.16798 44.40798...
# 2      2  LINESTRING (6.17137 44.39558, 6.17153 44.39557...

# %%
import geopandas as gpd
import shapely
from shapely.geometry import Point, LineString


start = [6.092259815779499, 44.397960224215]
mid = [6.148948, 44.421613999999984]
end =  [6.1679609208454735, 44.40870962465288]
point =  mid
wrc.GeoTools.calculate_route_distance(
    gdf_segments,
    0,
    point[1],  # swap order
    point[0],
)
# Out:
# Estimated UTM CRS: EPSG:32632
# {'estimated_utm_crs': <Projected CRS: EPSG:32632>
#  Name: WGS 84 / UTM zone 32N
#  Axis Info [cartesian]:
#  - E[east]: Easting (metre)
#  - N[north]: Northing (metre)
#  Area of Use:
#  - name: Between 6°E and 12°E, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Austria. Cameroon. Denmark. Equatorial Guinea. France. Gabon. Germany. Italy. Libya. Liechtenstein. Monaco. Netherlands. Niger. Nigeria. Norway. Sao Tome and Principe. Svalbard. Sweden. Switzerland. Tunisia. Vatican City State.
#  - bounds: (6.0, 0.0, 12.0, 84.0)
#  Coordinate Operation:
#  - name: UTM zone 32N
#  - method: Transverse Mercator
.41823999999998), (6.131738999999999, 44.418352), (6.133552, 44.41899600000001), (6.133826, 44.41912500000001), (6.1338740000000005, 44.419188999999996), (6.133826000000002, 44.41943), (6.13374, 44.419554000000005), (6.133713, 44.41968800000001), (6.133760999999999, 44.419811), (6.134437, 44.42003100000001), (6.1345019999999995, 44.42009000000001), (6.134426999999999, 44.420342), (6.134437, 44.420434), (6.134560999999999, 44.420519000000006), (6.135231000000001, 44.420691000000005), (6.135676000000001, 44.420519), (6.135913, 44.42045499999999), (6.13617, 44.42048700000001), (6.136513000000001, 44.420755), (6.136686827376801, 44.420826676882996), (6.137044, 44.420911), (6.137457, 44.421061), (6.138326, 44.421157999999984), (6.1390020000000005, 44.421269999999986), (6.139700000000001, 44.421473999999996), (6.140075, 44.421763999999996), (6.140215000000002, 44.42212899999999), (6.1402927714821, 44.422197769011994), (6.140419, 44.422247000000006), (6.140612000000002, 44.42225199999999), (6.140887306789699, 44.422167612489), (6.1409402575966, 44.42214977337199), (6.141158892295201, 44.422050520813), (6.141679702176301, 44.421705484878), (6.1421318855701, 44.42140639966), (6.1424809023067, 44.421199841708), (6.14257317649730 ...
# np.float64(0.11316958644348916)

# %%
display(wrc.GeoTools.swap_linestring_coords(gdf_segments.geometry.iloc[2]))
gdf_segments.geometry.iloc[2]
# Out:
# <LINESTRING (44.396 6.171, 44.396 6.172, 44.396 6.172, 44.396 6.173, 44.396 ...>
# <LINESTRING (6.171 44.396, 6.172 44.396, 6.172 44.396, 6.173 44.396, 6.173 4...>

# %%
line = geostages["geometry"].iloc[2]

gdf_segments = wrc.GeoTools.route_segment_meters(line, 10000, 12000)
wrc.GeoTools.leaflet_highlight_section(gdf_segments, swap_coords=True)
# Out:
# Map(center=[44.40870962465288, 6.1679609208454735], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
wrc.GeoTools.leaflet_highlight_route(line, 1000, swap_coords=True)
# Out:
# Map(center=[44.40482607979833, 6.099850710046146], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
geoseries = gpd.GeoSeries([geostages.iloc[0]["geometry"]])
geoseries
# Out:
# 0    LINESTRING Z (6.0427 44.55976 0, 6.04258 44.55...
# dtype: geometry

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np

from geographiclib.geodesic import Geodesic
from shapely import ops
from shapely.geometry import MultiLineString

geostages2 =geostages.copy()
# geostages2["geometry"] = geostages2["geometry"].apply(gpd.GeoSeries)
# geoseries = gpd.GeoSeries(geostages2.iloc[3])
#geostages2.iloc[2]["geometry"].coords

# %%
from shapely.geometry import LineString

geostages2.iloc[2]["geometry"].coords[0], geostages2.iloc[2]["geometry"].coords[-1]

geostages2["start"] = geostages2["geometry"].apply(
    lambda x: x.coords[0] if isinstance(x, LineString) else None
)
geostages2["finish"] = geostages2["geometry"].apply(
    lambda x: x.coords[-1] if isinstance(x, LineString) else None
)
geostages2
# Out:
#          name        stages                                      start  \
# 0   Shakedown   [Shakedown]  (6.042704031930801, 44.559764250197, 0.0)
# 1     SS 1/17   [SS1, SS17]  (6.264440450040201, 44.079301943751, 0.0)
# 2        SS 2         [SS2]    (6.0922598157795, 44.397960224215, 0.0)
# 3     SS 3/16   [SS3, SS16]    (6.1720265993721, 44.544598578142, 0.0)
# 4      SS 4/7    [SS4, SS7]    (6.0964818131896, 44.804749895108, 0.0)
# 5      SS 5-8    [SS5, SS8]        (6.196878999999999, 44.643949, 0.0)
# 6      SS 6-9    [SS6, SS9]                  (6.304178, 44.44236, 0.0)
# 7    SS 10/13  [SS10, SS13]    (5.3765337292667, 44.489641114902, 0.0)
# 8    SS 11/14  [SS11, SS14]    (5.3448707617935, 44.624669030287, 0.0)
# 9    SS 12/15  [SS12, SS15]    (5.6383926910448, 44.513366884411, 0.0)
# 10      SS 18        [SS18]  (7.331929681299101, 43.990417203574, 0.0)
#
#                                      finish  \
# 0   (6.0298841750004, 44.552857040276, 0.0)
# 1   (6.3100331508213, 43.982811558069, 0.0)
# 2   (6.2008078801752, 44.420944555289, 0.0)
# 3   (6.1495851364962, 44.517940317982, 0.0)
# 4   (6.0464240165479, 44.723124414211, 0.0)
# 5    (6.2212989177526, 44.57199506402, 0.0)
# 6    (6.308830381763, 44.372790086613, 0.0)
# 7   (5.2853453372715, 44.569941285717, 0.0)
# 8    (5.4074679393438, 44.64753343844, 0.0)
# 9   (5.7221531497862, 44.485567512913, 0.0)
# 10  (7.3661662453594, 43.944437668643, 0.0)
#
#                                              geometry
# 0   LINESTRING Z (6.0427 44.55976 0, 6.04258 44.55...
# 1   LINESTRING Z (6.26444 44.0793 0, 6.26483 44.07...
# 2   LINESTRING Z (6.09226 44.39796 0, 6.09239 44.3...
# 3   LINESTRING Z (6.17203 44.5446 0, 6.17176 44.54...
# 4   LINESTRING Z (6.09648 44.80475 0, 6.09661 44.8...
# 5   LINESTRING Z (6.19688 44.64395 0, 6.19691 44.6...
# 6   LINESTRING Z (6.30418 44.44236 0, 6.3039 44.44...
# 7   LINESTRING Z (5.37653 44.48964 0, 5.37648 44.4...
# 8   LINESTRING Z (5.34487 44.62467 0, 5.34494 44.6...
# 9   LINESTRING Z (5.63839 44.51337 0, 5.63837 44.5...
# 10  LINESTRING Z (7.33193 43.99042 0, 7.33196 43.9...

# %%
from geopy.distance import geodesic

def dist(row):
    try:
        return geodesic((row["lat"], row["lon"]), (row["prev_lat"], row["prev_lon"])).km
    except:
        return 0

# %%
from shapely.geometry import Point

def XlinestringFomCol(df, latcol="lat", loncol="lon", groupby=None):
    geometry = [Point(xy) for xy in zip(df[latcol], df[loncol])]
    dfg = gpd.GeoDataFrame(df, geometry=geometry)
    if groupby is not None:
        return dfg.groupby(groupby)["geometry"].apply(lambda x: LineString(x.tolist()))
    return LineString(dfg["geometry"].tolist())

# %%
c = [c for c in geostages2.iloc[2]["geometry"].coords]
cdf = pd.DataFrame.from_records(c, columns=["prev_lon", "prev_lat", "z"])
cdf["lat"] = cdf["prev_lat"].shift(-1)
cdf["lon"] = cdf["prev_lon"].shift(-1)

cdf["_dist"] = cdf.apply(lambda x: dist(x), axis=1)

cdf["_dist2"] = cdf.apply(
    lambda x: Geodesic.WGS84.Inverse(x["prev_lat"], x["prev_lon"], x["lat"], x["lon"])[
        "s12"
    ],
    axis=1,
)
cdf["_bearing"] = cdf.apply(
    lambda x: Geodesic.WGS84.Inverse(x["prev_lat"], x["prev_lon"], x["lat"], x["lon"])[
        "azi1"
    ],
    axis=1,
)

ddz = pd.DataFrame(
    cdf.apply(
        lambda x: Geodesic.WGS84.Inverse(
            x["prev_lat"], x["prev_lon"], x["lat"], x["lon"]
        ),
        axis=1,
    )
)[0].apply(pd.Series)

ddz["cumdist"] = ddz["s12"].cumsum()


ddz[["y", "x"]] = ddz.apply(lambda x: pd.Series(divmod(x["cumdist"], 1000)), axis=1)
ddz["y"] = 20 * ddz["y"]
ddz["azid"] = ddz["azi1"].diff()
ddz["u"] = 3 * np.sin(np.deg2rad(ddz["azi1"]))
ddz["v"] = 3 * np.cos(np.deg2rad(ddz["azi1"]))

ddz["u2"] = 3 * np.sin(np.deg2rad(ddz["azid"]))
ddz["v2"] = 3 * np.cos(np.deg2rad(ddz["azid"]))

# TO DO - use linestringFomLatLonCols in geotools.py
# ddz2 = linestringFomCol(ddz, latcol="lat1", loncol="lon1", groupby="y")
ddz2 = wrc.GeoTools.linestringFomLatLonCols(
    ddz, latcol="lat1", loncol="lon1", groupby="y"
)
plt.figure(figsize=(30, 30))
plt.quiver(
    ddz["x"],
    ddz["y"],
    ddz["u2"],
    ddz["v2"],
    angles="xy",
    pivot="tail",
    color="lightgrey",
    scale=100,
)
ax = plt.gca()
for i in ddz2.index:
    inset = inset_axes(
        ax,
        width=1,  # inch
        height=1,  # inch
        bbox_transform=ax.transData,  # data coordinates
        bbox_to_anchor=(-150, i - 5),  # data coordinates
        loc=3,
    )  # loc=lower left corner

    y, x = ddz2[i].xy
    inset.plot(x, y)
    # Add a marker at the start of the trace
    # Should probably color this green, and a red marker at end?
    inset.plot(x[0], y[0], "o", color="green")
    inset.plot(x[-1], y[-1], "o", color="red")

# %%
geostages.iloc[1]
# Out:
# name                                                  SS 1/17
# stages                                            [SS1, SS17]
# start               (6.264440450040201, 44.079301943751, 0.0)
# finish                (6.3100331508213, 43.982811558069, 0.0)
# geometry    LINESTRING Z (6.264440450040201 44.07930194375...
# Name: 1, dtype: object

# %%
from shapely.ops import nearest_points

# A stage route is a linestring
type(geostages.iloc[1]['geometry'])
route = geostages.iloc[1]["geometry"]
route
# Out:
# <LINESTRING Z (6.264 44.079 0, 6.265 44.079 0, 6.265 44.079 0, 6.265 44.079 ...>

# %%
import geopandas as gpd
telem_gdf = gpd.GeoDataFrame(
    df_telemetrydata,
    geometry=gpd.points_from_xy(df_telemetrydata.lon, df_telemetrydata.lat),
    crs="EPSG:4326",
)
telem_gdf.head()
# Out:
#    accx  accy  altitude  brk driverid  gear  heading   kms      lat       lon  \
# 0     0     0         0    0    85321     0      144  28.1 -0.49503  36.26853
# 1     0     0         0    0    85321     0      144  28.1 -0.49503  36.26853
# 2     0     0         0    0    85321     0      146  28.1 -0.49503  36.26853
# 3     0     0         0    0    85321     0      148  28.1 -0.49503  36.26853
# 4     0     0         0    0    85321     0      148  28.1 -0.49503  36.26853
#
#    ... speed     status  throttle track            utx  \
# 0  ...     0  Competing         0        1742568152900
# 1  ...     0  Competing         0        1742568149700
# 2  ...     0  Competing         0        1742568146500
# 3  ...     0  Competing         0        1742568143300
# 4  ...     0  Competing         0        1742568140100
#
#                          _rally_stageid                           _carentryid  \
# 0  bf6db08e-bb61-4ff2-aa41-669dbda78a20  97209e11-2ea3-4327-be4b-bc7bde735a66
# 1  bf6db08e-bb61-4ff2-aa41-669dbda78a20  97209e11-2ea3-4327-be4b-bc7bde735a66
# 2  bf6db08e-bb61-4ff2-aa41-669dbda78a20  97209e11-2ea3-4327-be4b-bc7bde735a66
# 3  bf6db08e-bb61-4ff2-aa41-669dbda78a20  97209e11-2ea3-4327-be4b-bc7bde735a66
# 4  bf6db08e-bb61-4ff2-aa41-669dbda78a20  97209e11-2ea3-4327-be4b-bc7bde735a66
#
#                                         _telemetryID     _name  \
# 0  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 1  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 2  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 3  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 4  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#
#                     geometry
# 0  POINT (36.26853 -0.49503)
# 1  POINT (36.26853 -0.49503)
# 2  POINT (36.26853 -0.49503)
# 3  POINT (36.26853 -0.49503)
# 4  POINT (36.26853 -0.49503)
#
# [5 rows x 22 columns]

# %%
from shapely.geometry import LineString
telemroute = LineString(telem_gdf.geometry.tolist())
telemroute
# Out:
# <LINESTRING (36.269 -0.495, 36.269 -0.495, 36.269 -0.495, 36.269 -0.495, 36....>

# %%
telemroute.coords[0], route.coords[0]
# Out:
# ((36.26853, -0.49503), (6.264440450040201, 44.079301943751, 0.0))

# %%
from shapely.geometry import mapping

from ipyleaflet import Polyline

m = wrc.GeoTools.simple_stage_map(geostages)

def add_route_linestring_to_map(m, route, color="red", weight=4, opacity=0.8, fill=False):
    route_coords = mapping(route)["coordinates"]
    # Create a Polyline object
    # Note: ipyleaflet expects coordinates as [lat, lon] while Shapely uses [lon, lat]
    # So we need to swap the coordinates
    route_layer = Polyline(
        locations=[[c[1], c[0]] for c in route_coords],
        color=color,
        weight=weight,
        opacity=opacity,
        fill=fill,
    )

    # Add the route to the map
    m.add_layer(route_layer)

add_route_linestring_to_map(m, geostages.iloc[2]["geometry"],"green")
add_route_linestring_to_map(m, telemroute, "black")

m
# Out:
# Map(center=[np.float64(44.376536632100496), np.float64(6.33689497539215)], controls=(ZoomControl(options=['pos…

# %%
# Project points onto the route and compute distance along the route
def project_point(point, route):
    nearest = nearest_points(route, point)[1]
    return nearest, route.project(nearest)


telem_gdf["projected"], telem_gdf["distance_along_route"] = zip(
    *telem_gdf.geometry.apply(lambda p: project_point(p, route))
)
telem_gdf.head()
# Out:
#    accx  accy  altitude  brk driverid  gear  heading   kms      lat       lon  \
# 0     0     0         0    0    85321     0      144  28.1 -0.49503  36.26853
# 1     0     0         0    0    85321     0      144  28.1 -0.49503  36.26853
# 2     0     0         0    0    85321     0      146  28.1 -0.49503  36.26853
# 3     0     0         0    0    85321     0      148  28.1 -0.49503  36.26853
# 4     0     0         0    0    85321     0      148  28.1 -0.49503  36.26853
#
#    ... throttle  track            utx                        _rally_stageid  \
# 0  ...        0         1742568152900  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# 1  ...        0         1742568149700  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# 2  ...        0         1742568146500  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# 3  ...        0         1742568143300  bf6db08e-bb61-4ff2-aa41-669dbda78a20
# 4  ...        0         1742568140100  bf6db08e-bb61-4ff2-aa41-669dbda78a20
#
#                             _carentryid  \
# 0  97209e11-2ea3-4327-be4b-bc7bde735a66
# 1  97209e11-2ea3-4327-be4b-bc7bde735a66
# 2  97209e11-2ea3-4327-be4b-bc7bde735a66
# 3  97209e11-2ea3-4327-be4b-bc7bde735a66
# 4  97209e11-2ea3-4327-be4b-bc7bde735a66
#
#                                         _telemetryID     _name  \
# 0  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 1  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 2  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 3  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
# 4  /35c61a2f-46b2-41b7-8af9-a19ceea5583d/ss03fou_...  Fourmaux
#
#                     geometry                  projected distance_along_route
# 0  POINT (36.26853 -0.49503)  POINT (36.26853 -0.49503)             0.159913
# 1  POINT (36.26853 -0.49503)  POINT (36.26853 -0.49503)             0.159913
# 2  POINT (36.26853 -0.49503)  POINT (36.26853 -0.49503)             0.159913
# 3  POINT (36.26853 -0.49503)  POINT (36.26853 -0.49503)             0.159913
# 4  POINT (36.26853 -0.49503)  POINT (36.26853 -0.49503)             0.159913
#
# [5 rows x 24 columns]

# %%
# ELEVATION

# Contours:
# -  https://medium.com/analytics-vidhya/creating-contour-lines-on-folium-map-with-python-b7994e67924b
# - https://github.com/jupyter-widgets/ipyleaflet/issues/503#issuecomment-797442811
# - https://stackoverflow.com/questions/65634602/plotting-contours-with-ipyleaflet

# %%
# TO DO - use claude to generate a py version
# that does not use GDAL or rasterio  
# which aren't availbale in wasm pyodide shinylive python environment

# %%
# Example usage demonstrations
# 1. From GeoPandas row
# elevations = get_route_elevations(routes_gdf.iloc[0])

# 2. From Shapely Geometry
# elevations = get_route_elevations(routes_gdf.iloc[0].geometry)

# 3. From GeoJSON dictionary
# geojson_route = {
#     "type": "Feature",
#     "geometry": {
#         "type": "LineString",
#         "coordinates": [
#             [-122.4194, 37.7749],  # San Francisco
#             [-118.2437, 34.0522]   # Los Angeles
#         ]
#     }
# }
# elevations = get_route_elevations(geojson_route)

# 4. From GeoJSON string
# geojson_string = json.dumps(geojson_route)
# elevations = get_route_elevations(geojson_string)

# %%
route = geostages.iloc[1]["geometry"]
route = geostages.iloc[1]
# elevations = wrc.GeoTools.route_elevations(route)
## can also modify the gpd
elevations = wrc.GeoTools.route_elevations(route, mode="augmented")
# returns linestring
# routes_gdf.loc[index, 'geometry'] = process_route_elevations(routes_gdf.iloc[index], mode='augmented')
"""
routes_gdf['geometry'] = routes_gdf.apply(
    lambda row: process_route_elevations(row, mode='augmented'), 
    axis=1
)
"""
elevations
# Out:
# <LINESTRING Z (6.264 44.079 709, 6.265 44.079 693, 6.265 44.079 693, 6.265 4...>
